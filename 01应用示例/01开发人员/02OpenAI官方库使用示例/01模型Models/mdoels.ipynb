# %% [markdown]
#  1、查阅 开始前必读 [获取白菜APIKEY](https://doc.baicaigpt.com/getting_started/baicai_api_key)

# %% [markdown]
# 2、安装OpenAI Python库

# %%
pip install openai==0.28
# Out:
# ...
#
# ...

# %% [markdown]
# 3、替换你的白菜API_KEY，运行一下代码
# 注：API_KEY为baicai-XXX，不需要包括Bearer，保留双引号

# %%
import openai

openai.api_key = "你的白菜API_KEY"
openai.api_base = "https://api.baicaigpt.com/v1"

engines = openai.Model.list()
print(engines)
# Out:
# {
#   "object": "list",
#   "data": [
#     {
#       "id": "dall-e-3",
#       "object": "model",
#       "created": 1698785189,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-0613",
#       "object": "model",
#       "created": 1686587434,
#       "owned_by": "openai"
#     },
#     {
#       "id": "text-embedding-3-large",
#       "object": "model",
#       "created": 1705953180,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct-0914",
#       "object": "model",
#       "created": 1694122472,
#       "owned_by": "system"
#     },
#     {
#       "id": "dall-e-2",
#       "object": "model",
#       "created": 1698798177,
#       "owned_by": "system"
#     },
#     {
#       "id": "whisper-1",
#       "object": "model",
#       "created": 1677532384,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "babbage-002",
#       "object": "model",
#       "created": 1692634615,
#       "owned_by": "system"
# ...

# %% [markdown]
# 4、查看输出结果，正常如下

# %% [markdown]
# ```json
# {
#   "object": "list",
#   "data": [
#     {
#       "id": "dall-e-3",
#       "object": "model",
#       "created": 1698785189,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-0613",
#       "object": "model",
#       "created": 1686587434,
#       "owned_by": "openai"
#     },
#     {
#       "id": "text-embedding-3-large",
#       "object": "model",
#       "created": 1705953180,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct-0914",
#       "object": "model",
#       "created": 1694122472,
# ...
#       "owned_by": "system"
#     }
#   ]
# }
# ```
# ```

# %% [markdown]
# 5、 登录 [白菜GPT-会员中心](https://shop.baicaigpt.com/#/account)，查看消费记录（可选）
