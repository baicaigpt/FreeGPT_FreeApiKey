# %% [markdown]
# #1/5 查阅 开始前必读 获取白菜APIKEY

# %% [markdown]
# #2/5 参考如下示例代码，替换为你自己的白菜API_KEY

# %%
import http.client

conn = http.client.HTTPSConnection("api.baicaigpt.com")
payload = ''
headers = {
   'Authorization': 'Bearer 你的白菜API_KEY',
}
conn.request("GET", "/v1/models", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {
#   "object": "list",
#   "data": [
#     {
#       "id": "dall-e-3",
#       "object": "model",
#       "created": 1698785189,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-0613",
#       "object": "model",
#       "created": 1686587434,
#       "owned_by": "openai"
#     },
#     {
#       "id": "text-embedding-3-large",
#       "object": "model",
#       "created": 1705953180,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct-0914",
#       "object": "model",
#       "created": 1694122472,
#       "owned_by": "system"
#     },
#     {
#       "id": "dall-e-2",
#       "object": "model",
#       "created": 1698798177,
#       "owned_by": "system"
#     },
#     {
#       "id": "whisper-1",
#       "object": "model",
#       "created": 1677532384,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "babbage-002",
#       "object": "model",
#       "created": 1692634615,
#       "owned_by": "system"
# ...

# %% [markdown]
# #3/5 点击运行，查看运行结果，正常输出内容如下

# %%
{
  "object": "list",
  "data": [
    {
      "id": "dall-e-3",
      "object": "model",
      "created": 1698785189,
      "owned_by": "system"
    },
    {
      "id": "gpt-3.5-turbo-0613",
      "object": "model",
      "created": 1686587434,
      "owned_by": "openai"
    },
    {
      "id": "text-embedding-3-large",
      "object": "model",
      "created": 1705953180,
      "owned_by": "system"
    },
    {
      "id": "gpt-3.5-turbo-instruct-0914",
      "object": "model",
      "created": 1694122472,
...
  ]
}

# %% [markdown]
# #4/5 登录shop.baicaigpt.com，查看消费记录（可选）

# %% [markdown]
# #5/5 结束
